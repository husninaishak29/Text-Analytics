# %%
# Nur Amira Hanina Binti Khairul Nazmi (IS01081120)
# Marsya Nur Iman Binti Mohd Ishak (IS01081187)


import datetime #provide functions to work with dates and times
import requests #make HTTP requests to web APIs
import re

#URL for Shopee product page
url = 'https://shopee.com.my/-Max-6-packs-Dendeng-Nyet-Berapi-by-Khairulaming-i.364740282.25363171499?sp_atk=b600ac55-0f23-4b9b-af94-18a0d7fbca5d'

#function to find pattern in the URL
r = re.search(r'i\.(\d+)\.(\d+)', url)
if r:
    shop_id, item_id = r.group(1), r.group(2)
else:
    print("Invalid URL")
    exit()

def convert_ctime_to_datetime(ctime_value):
    """Converts a ctime value (potentially a timestamp) to a datetime object.

    Args:
        ctime_value: The value retrieved from the 'ctime' field in the API response.

    Returns:
        A datetime object representing the converted time, or None if conversion fails.
    """

    try:
        timestamp = int(ctime_value)
        datetime_obj = datetime.datetime.fromtimestamp(timestamp)
        return datetime_obj.strftime("%Y-%m-%d %H:%M")  # Format as "YYYY-MM-DD HH:MM"
    except (ValueError, TypeError):
        print(f"Error converting ctime value: {ctime_value}")
        return None
    
offset = 0
while True:
    ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
    #ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'

    try:
        # Send API request and handle potential errors
        response = requests.get(ratings_url)
        #response.raise_for_status()  # Raise an exception for non-200 status codes

        data = response.json()

        # Limit for the number of pages (3 pages)
        page_limit = 3

        

        if 'data' in data and 'ratings' in data['data'] and data['data']['ratings']:
            for rating in data['data']['ratings']:
                try:
                    datetime_str = convert_ctime_to_datetime(rating['ctime'])

                    def extract_date(datetime_str):
                        """Extracts only the date portion (YYYY-MM-DD) from a formatted datetime string.

                        Args:
                            datetime_str: The string containing the date and time in a format like "YYYY-MM-DD HH:MM".

                        Returns:
                            The extracted date portion as a string (YYYY-MM-DD), or None if the format is invalid.
                        """
                        if datetime_str:
                            try:
                                # Split the string at the space separator
                                date_part, _ = datetime_str.split(" ")
                                return date_part
                            except ValueError:
                                print(f"Invalid datetime format: {datetime_str}")
                                return None
                        else:
                            return None

                    date_only = extract_date(datetime_str)
                    if date_only:
                        print(f"Review Date: {date_only}")
                    else:
                        print("Failed to extract date from ctime")
                except KeyError:
                    print("Review is missing a 'ctime' field")
                print(rating['author_username'])
                print(rating['comment'])
                print('-' * 80)
        else:
            print("No ratings found in the response")

    except requests.exceptions.RequestException as e:
        print(f"Error making API request: {e}")

    offset += 20

# %%
# Nur Amira Hanina Binti Khairul Nazmi (IS01081120)
# Marsya Nur Iman Binti Mohd Ishak (IS01081187)


import datetime #provide functions to work with dates and times
import requests #make HTTP requests to web APIs
import re

#URL for Shopee product page
url = 'https://shopee.com.my/-Max-6-packs-Dendeng-Nyet-Berapi-by-Khairulaming-i.364740282.25363171499?sp_atk=b600ac55-0f23-4b9b-af94-18a0d7fbca5d'

#function to find pattern in the URL
r = re.search(r'i\.(\d+)\.(\d+)', url)
if r:
    shop_id, item_id = r.group(1), r.group(2)
else:
    print("Invalid URL")
    exit()

def convert_ctime_to_datetime(ctime_value):
    """Converts a ctime value (potentially a timestamp) to a datetime object.

    Args:
        ctime_value: The value retrieved from the 'ctime' field in the API response.

    Returns:
        A datetime object representing the converted time, or None if conversion fails.
    """

    try:
        timestamp = int(ctime_value)
        datetime_obj = datetime.datetime.fromtimestamp(timestamp)
        return datetime_obj.strftime("%Y-%m-%d %H:%M")  # Format as "YYYY-MM-DD HH:MM"
    except (ValueError, TypeError):
        print(f"Error converting ctime value: {ctime_value}")
        return None
    
offset = 0
page_limit = 1

while True:
    ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
    #ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'

    try:
        # Send API request and handle potential errors
        response = requests.get(ratings_url)
        #response.raise_for_status()  # Raise an exception for non-200 status codes

        data = response.json()

        page_limit = 1

        if 'data' in data and 'ratings' in data['data'] and data['data']['ratings']:

            for page_number in range(page_limit):
                print(f"Processing Page: {page_number + 1}")
            
                for rating in data['data']['ratings']:
                    try:
                        datetime_str = convert_ctime_to_datetime(rating['ctime'])

                        def extract_date(datetime_str):
                            """Extracts only the date portion (YYYY-MM-DD) from a formatted datetime string.

                            Args:
                                datetime_str: The string containing the date and time in a format like "YYYY-MM-DD HH:MM".

                            Returns:
                                The extracted date portion as a string (YYYY-MM-DD), or None if the format is invalid.
                            """
                            if datetime_str:
                                try:
                                    # Split the string at the space separator
                                    date_part, _ = datetime_str.split(" ")
                                    return date_part
                                except ValueError:
                                    print(f"Invalid datetime format: {datetime_str}")
                                    return None
                            else:
                                return None

                        date_only = extract_date(datetime_str)
                        if date_only:
                            print(f"Review Date: {date_only}")
                        else:
                            print("Failed to extract date from ctime")
                    except KeyError:
                        print("Review is missing a 'ctime' field")
                    print(rating['author_username'])
                    print(rating['comment'])
                    print('-' * 80)
            else:
                print("No ratings found in the response")

    except requests.exceptions.RequestException as e:
        print(f"Error making API request: {e}")

    offset += 20
# Out:
# Processing Page: 1
# Review Date: 2024-03-01
# s*****a
# Quality:good
# Taste:very good
#
# Barang sampai dengan selamat,packaging sangat2 lah tebal..rasa belom try lagi,harap2 kena dengan tekak boleh gu mkn dengan sambal nyet berapi..terima kasih yer.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-26
# a*****n
# Taste:Well balanced and aromatic taste
# Quality:Great
#
# Sedap, manis masin yang balance, ada aroma tersendiri yang kuat dan unik. Daging lembut dan sesuai dimakan untuk kids or elders, my mom pun suprisingly suka and request untuk order lagi.
# --------------------------------------------------------------------------------
# Review Date: 2024-03

# --------------------------------------------------------------------------------
# Review Date: 2024-03-13
# a*****n
# Quality:terbaik
# Taste:kene dgn selera
#
# Jujur ckp Xmenyesal beli..byk kali try xdpt2..
# Akhirnya..dendeng dia mmg kene ngn selera..
# Makan plak dgn lemang..🫨
# rasa rempah dia..manis dendeng pn ok..
# Pedas (2.5/5) dia pn ok..*btw dendeng mmg xpedas sgt pn kn..klu nk pedas masak la sdri..ye dop?
# --------------------------------------------------------------------------------
# Review Date: 2024-02-24
# s*****6
# Received the 6 packs Dendeng Nyet Berapi in very good condition 〰️ Well-packed & bubbled-wrapped in a plastic 👍🏻👍🏻👍🏻
#
# However, we cld only buy maximum of 6 packs.
#
# I'm happy with my purchase.
#
# Price is competitive with other sellers especially with discount offered.
#
# Will come back & buy more.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-26
# a*****1
# Taste:sedapp
# Quality:bagus
#
# rasa manis pedas light2 masin semua ok. haritu order ada tumpah bocor so chat hotline pstu diorg send pack ganti yg baru. rasa dendeng ni mcm campuran serunding+daging kicap camtu for me. apapon mmg best and akan repeat heheh
# --------------------------------------------------------------------------------
# Review Date: 2024-02-27
# s*****a
# Taste:sedapp
# Quality:very good
#
# Struggle battle dendeng ni! Fuhhhh. Nak buat stok untk bulan puasa nanti. Daging nii sedappp! Manis cukup rasa. Awal2 makan tk rasa pedas, lama2 mkn lebih sikit ada rasa pedasnya. Apapun tahniah KA!
# --------------------------------------------------------------------------------
# Review Date: 2024-02-22
# n*****7
# Quality:Terbaik..baik dari segi packaging rase semua mantap..
# Taste:Sedap..
#
# Hasil battle dpt beli 3.. alhamdulillah umi sye approve..siap suruh beli lg utk buat stok puasa nnt.. texture lerai senang nk mkn..mmg sesuai utk org tua bdk2..cuma xpedas..pair dgn sambal nyet mmg padu rase die.. overall sedap..
# --------------------------------------------------------------------------------
# Review Date: 2024-02-27
# s*****o
# Quality:bungkusan semua ok tak ada pecah cuma lebih menyenangkan jika menggunakan packaging ziplock
# Taste:dendeng sedap dengan aroma yang kuat dan ada rasa macam serunding sikit mungkin sebab tekstur daging yang relai. Daging agak keras tapi untuk orang muda ok saja. Tahap kepedasan sesuai untuk semua umur.
#
# Sedap, mudah, pantas untuk bersahur 👍🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-02-28
# s*****2
# Taste:okey
# Quality:okey
#
# Penghantaran cepat dan pembungkusan kemas. Barang yang di oder sama seperti dalam gambar. Tak pedas boleh lah budak2 nak makan.   Akan repeat oder lagi di kedai anda akan datang. Terima kasih
# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# v8gdz0tl7j
# Quality:Sangat bagus
# Taste:Sedap sangat
#
# Gigih ya saya battle kali ni, nasib baik dapat, dah makan dah, memang sedap sangat, terbaiklah KA buat dendeng ni, rasanya sangat sedap sekali ya gaisss
# --------------------------------------------------------------------------------
# Review Date: 2024-03-09
# n*****a
# Quality:okay. Standard makanan retort.
# Taste:sedap tapi sedap yang biasa je. Rempah cukup.
#
# Taste wise: sedap. Ada rasa manis kicap sikit. Rasa pedas tu ada tapi hujung2 baru rasa pedas tu so enjoy la makan.
# Texture wise: daging dia lerai2 macam serunding so lagi suka kalau daging ketul2.
# Overall: sedap tapi sedap yang biasa je.
# --------------------------------------------------------------------------------
# Review Date: 2024-03
# Daging dendeng sedap 😍 Husband pun approved. Cuma lepasni harap bungkusan ada ziplock. Senang nak simpan balik dlm peti ais. Packaging mantap 🤝🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-02-23
# s*****a
# Taste:Sedap yg simple and nice! Secukup rasa, pedas pun cukup.
# Quality:Sedap just nice secukup rasa pedas seimbang.
#
# Packaging saja kena buat ziplock bag. Taste wise, sedap simple & nice! Delivery laju terbaikk!
# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# zulfeeqarzaini
# Quality:sangat elok
# Taste:sedap gilaaaaa
#
# Sedap sangat😭pastu packaging dia tebal and x sangka aku jadi org terawal dapat beli Dendeng nyet ni...loveeeeeee❤️❤️❤️❤️❤️overall rasa,penjagaan mmg tiptop lahhhhh.... khairulaming the best sbb pentingkan penjagaan dan kerapian semuaaaaaa
# --------------------------------------------------------------------------------
# Review Date: 2024-02-28
# norazrinhassan
# Quality:Superb
# Taste:Superb, not as sweet as previous comment plus a little spicy
#
# Spicy 3 of 5
# Taste 5 of 5
# Quantity good as top up menu
#
# Overall 5 stars
# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# sunflowerbaby_96
# Taste:sedap sgt !
# Quality:all perfect ! Delivery laju.
#
# Daging sedap sgt ! Sbgi pencinta pedas kalau tambah pedas sikit lgi mantappp 👍🏻
# Tp saya tetap bg 10/10 ❤️
# --------------------------------------------------------------------------------
# Review Date: 2024-02-23
# anisasabri
# Taste:sedap je
# Quality:kualiti bagus
#
# Sedap cuma manis tu agak terasa. Tak pedas sgt. Isi daging pun ok. Buat makan dengan roti time sahur sesuai sgt la.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-20
# n*****_
# Taste:sedap
# Quality:terbaik
#
# Sedappp sangattttt!! I think 2nd batch ni pedas sikit kot sebab tengok review yg beli 1st batch cakap tak pedas tapi ni pedas sikit TAPI TETAP LURVEEEEEEE 😍 Makan ni utk buka puasa semalam terus imagine pagi raya makan ni dgn ketupat uollsss 😂 Okay nanti nak beli lagiiii sebab SATU BUNGKUS TAK CUKUP YE 😂 &&& postage sangat terpaling laju ye 👍🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-02-29
# haniiayumie
# Taste:sedapp
# Quality:👍🏼👍🏼👍🏼
#
# Sampai dengan selamat . . Rasanyaa sedapp , puas hatii .. . Terima kasih KA , menghasilkan product yg terbaik n sedapp ❤️
# --------------------------------------------------------------------------------
# Review Date: 2024-02-21
# fttinaqila711.
# Taste:Sedap juga dendeng ni makan dengan nasi panas2 & telur. Akan repeat inshaAllah utk buat stock !! Terima kasih.
# Quality:Alhamdulillah selamat sampai, packaging semua ok .
# --------------------------------------------------------------------------------
# Review Date: 2024-03-06
# ananbundleent
# Quality:balut nice
# Taste:belum rasa
#
# Packaging nice
# Sampai cepat
# Alhamdullilah sempat kaut 6 hehe kali keberapa tah cuba
# Hope memenuhi cita rasa ! Takdan makan lagii ,but soon!
# --------------------------------------------------------------------------------
# Review Date: 2024-02-20
# _*****a
# Taste:sedappp 😋
# Quality:terbaikk 👍🏻
#
# service dari seller sgt mantap yaa..staff KA laju buat keja..16hb order, 17hb shipped out, 19hb sampai 👍🏻

# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# a*****0
# Quality:Nice
# Taste:Delicious
#
# Dagingnya lembut dan senang untuk dikunyah,tahap kemasinan dia ok.tak masin sangat,cuma tak pedas je la.dia ade pedas sikit hujung2 tu.apa2 pun nnti sy repeat order lagi
# --------------------------------------------------------------------------------
# Review Date: 2024-02-22
# s*****r
# Taste:sedappp
# Quality:terbaik
#
# Dendeng nyet memang terbaik. Makan dengan nasi panas dan telur mata goreng plus sambal nyet berapi. Memang terbaik. Keep up the good job KA. 👍
# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# lyanniearz
# Quality:Ok
# Taste:Not spicy
#
# Tekstur seperti serunding basah, rasa berempah dan manis.
# Kalau pedas mmg awesome.
# Penghantaran laju, order jumaat, ahad dh sampai.
# Repeat? Maybe not.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-21
# biskutmelo
# Quality:packaging secured
# Taste:not yet to taste but will add response soon
#
# Dendeng 1st batch shopee after dendeng tiktok batch. Berjaya secure 1 sb kalah battle kt tiktok aritu packaging puas hati delivery pun laju ooo 3 hari sampai sabahtak rasa lagi nnt kita edit balik.hihi. taktau la yg ini yg da improvise or not yg dri 1st batch tiktok. Nnt kita rasa tau pastu komen.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-03
# j*****a
# Quality:baik
# Taste:baik
#
# Sedap. Rasa pedas dan manis seiring. Semua orang boleh makan tapi ikut tekak masing masing lah kan. For me and family overall okay. Dari segi packaging je boleh improvise sikit. Sebab quantity dendeng tu banyak, lagi bagus kalau ada ziplock so boleh simpan sikit sikit. Everything okay 👍🏼👍🏼👍🏼
# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# d*****h
# Taste:pedas 4/10 tak pedas sgt tpi pedas masi terasa hehehe
# Quality:tiptop !
#
# Makan dgn nasi panas2 mmg terbaik jrg2 dpt jdi fast buyer ni , apa pun penghantaran superr pantass walaupun kt sabah..tekejut juga mcm bru ja oder dendeng ni 🤣
# --------------------------------------------------------------------------------
# Review Date: 2024-02-29
# syimsyimmi
# Quality:packaging elok. Delivery laju within 2hari sampai (kl / kulim)
# Taste:Pedas tu after taste. 1st bite tu manis
#
# Rasa okay boleh lah buat lepas kempunan product KA.. Sedap (8/10) ❤️
# --------------------------------------------------------------------------------
# Review Date: 2024-02-27
# i*****_
# Taste:sedap kena dengan selera
# Quality:top notch
#
# Akhir dapat jugak. Daging banyak tak kedekut, rasa agak pedas sikit (untuk saya yang tak tahan pedas). Nanti repeat. Owh packaging tebal memang secure habis.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-05
# f*****a
# Quality:good quality and superbb!! 🫶🏻😭
# Taste:sedap nak mampus tolong beli
#
# memang sedap gila daging dendeng KA. kean dengan tekak. cukup rasa manis masin and pedas. sesuai makan for sahur and berbuka sebab mudah. for single person, satu pack boleh makan sampai 5 kali tau. hehehe i buat berbuka puasa haritu memang senang sangat. especially yang bekerja. and jimat!! kali ke dua repeat order. last haritu order time first launch. nak repeat kali kedua ni pun susah teruk mat 😭😭
# --------------------------------------------------------------------------------
# Review Date: 2024-02-19
# s*****r
# Quality:very good
# Taste:Pedas berapi & manis
#
# Penghantaran yang sangat cepat - order hari Jumaat & sampai hari Isnin. Barang dibalut dengan bubble wrap yang tebal. Kandungan makanan cukup untuk 2 orang makan & rasa daging nyet berapi ini mempunyai pedas & manis yang seimbang. Cara pemanasan saya tidak ikut cara yg tertulis di bekas, saya buat cara letakkan semua daging di dalam mangkuk & panaskan di dalam microwave selama 3 minit. Okay juga cara ini :)
# --------------------------------------------------------------------------------
# Review Date: 2024-03-04
# a*****a
# Taste:good
# Quality:good
#
# Dendeng dah selamat sampai lama.. rasa semua okay, sesuai untuk buat sahur bulan ramadhan nanti.. kalau dimakan dengan sambal nyet lagi padu jadinya.. overall semua okay 👌🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-02-26
# pamietakasago
# Penghantaran yang cepat , services  yang bagus serta harga yang berbaloi untuk barangan/produk ini .Saya mencadangkan peniaga ini kepada anda semua sekiranya membeli dengan mereka.
# --------------------------------------------------------------------------------
# No ratings found in the response
# Processing Page: 1
# Review Date: 2024-02-21
# n*****a
# Taste:sedap
# Quality:tiptop
#
# Alhamdulillah selamat sampai dalam masa 2 hari je.. sedap.. bg sy yg xmkan pedas, sy suka yg nie.. please jgn tambah lg kepedasan.. klu nk tambah pedas, jgn tukar yg nie taw.. buat 1 versi pedas n 1 versi yg nie.. yg pedas tu tukar packaging kaler oren ke.. sekadar cadangan..
# --------------------------------------------------------------------------------
# Review Date: 2024-03-02
# harithsyaza88
# Quality:great
# Taste:good
#
# Kemas dan rapi di dalam bubble wrap. Very quick delivery too. Sedap itu subjective but we like it so yeah that's all that matters
# --------------------------------------------------------------------------------
# Review Date: 2024-02-28
# n*****2
# Quality:ok
# Taste:ok
#
# Thank you seller.
# Product delivery satistied.
# What a bargain.
# Hope you can sell more with the discounted price.
# The material is nice. Color is nice.
# Im truly happy with this.
# ...
# Review Date: 2024-03-20
# f*****s
# Quality:👍
# Taste:👍
#
# Item received in good condition but delivery a bit slow ..
# --------------------------------------------------------------------------------
# Review Date: 2024-03-21
# epajid
# Dah 3 kali beli, mmg puas hati. Kena dengan tekak saya. Tiap kali makan nasi putih mesti ada dendeng sekali
# --------------------------------------------------------------------------------
# Review Date: 2024-03-21
# epajid
# Dah 3 kali beli, mmg puas hati. Kena dengan tekak saya. Tiap kali makan nasi putih mesti ada dendeng sekali
# --------------------------------------------------------------------------------
# Review Date: 2024-03-18
# r*****z
# 🛂 Terima item dgn baik
# 🚚 Thanks To Courier Service
# 📦 Pembungkusan sempurna & selamat
# ♻️ Material yang berkualiti
# 👥 Penjual yang mesra pelanggan
# 🔊 Recommend sangat
# 🤑 Murah dari yang lain
# 🛒 Jom SHOPPIE 🛍
# --------------------------------------------------------------------------------
# Review Date: 2024-02-23
# a*****n
# Quality:superb!!!
# Taste:sedap, tak pedas sgt, budak boleh makan.
#
# Barang dah sampai selasa lepas tapi harini baru try. sedap sangat. haritu dapat beli 1 packet je. nanti nak try battle beli 6paket terus inshaallah utk simpan time puasa 😋👏🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-03-14
# idaamylea
# Quality:Baikk
# Taste:Pedas Manis
#
# Dapat ni rsa mcam menang award 😂 ! Kli ke berapa ntah battle bru dapat . Overall mmng sedap daging dendeng nih pedas dia kita bgi 3/10 jer kesedapan dia kita bgi 1000/10 ⭐️⭐️⭐️⭐️
# --------------------------------------------------------------------------------
# Review Date: 2024-02-18
# l*****g
# Taste:Sedap boleh repeat lagi
# Quality:Sesuai untuk dimakan semua peringkat umur
#
# First bukak, bau menusuk hidung. Bau sedap. Makan tu memang secukup rasa. Lagi sedap makan dgn sambal. Dia complete each other. For someone yang mungkin tak makan manis, mungkin akan rasa manis sikit. Tapi for me rasa just nice especially kalau makan dgn sambal. Overall sedap and memang akan repeat lagi.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-27
# f*****t
# Taste:sedappp!! Worth it!
# Quality:very good
#
# Sedap!! Tp batch kalini i dapat pedas. Agaknya dia tambah level kepedasan kot. Serius sedap. Xde pun rasa kicap manis semata. Mmg rasa dia blend elok. Cuma x best daging dia hancur mcm makan serunding.. lain semua purrfectt! 8/10! Worth it my battle!
# --------------------------------------------------------------------------------
# Review Date: 2024-02-18
# m*****7
# Taste:excellent
# Quality:excellent
#
# Alhamdulillah order cepat sangat sampai. Tak rasa lagi sebab nk buat stok masa puasa tapi kepercayaan dari sambal nyet yg sodap saya pasti dendeng ni pun in sha allah sodap jugaaaaa ❤️
# --------------------------------------------------------------------------------
# Review Date: 2024-03-21
# i*****y
# Sampai dalam keadaan baik. Dapat grab dua belas pack dalam masa dua hari.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-21
# i*****y
# Sampai dalam keadaan baik. Dapat grab dua belas pack dalam masa dua hari.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-22
# p*****h
# Taste:sedap!
# Quality:10/10
#
# wrapping tebal dooh, beli 4 untuk bagi mama ayah dengan mertua hehe. ayah haritu dah masak ikut resepi khairul aming dia cakap sedap ni kita beli terus dendeng nyet bagi ayah rasa 😍
# --------------------------------------------------------------------------------
# Review Date: 2024-02-29
# syariza1610
# Beli sebab nak test rasa je. Satu family cakap sedap. Saya rasa pun sedap, rasa dendeng. Cuma kalau dapat kurangkan manis sikit je...perfect ikut tekak saya. Tapi kalau tekak orang lain mungkin ok je manis tu.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-26
# m*****n
# Taste:sedap
# Quality:very good
#
# Batch ke 2 lebih pedas dari batch 1…saya suka sebab lebih pedas, serta cukup rasa dengan bau daun limau tu…tapi bagi anak dengan suami dorg lebih suka yang version 1 yang kurang pedas tu..sedap tu subjective tak semua orang lidah yang sama..apa pun terbaik aming
# --------------------------------------------------------------------------------
# Review Date: 2024-03-04
# n*****2
# Taste:delicious
# Quality:good
#
# penat juga battle setiap hari tapi alhamdulillah dapat jugak 3 packet. blh la buat stock untuk bulan Ramadhan nnt. mudah jee xambil masa yang lama pun
# --------------------------------------------------------------------------------
# No ratings found in the response
# Processing Page: 1
# Review Date: 2024-02-22
# nurulnadzirah49
# Quality:Sedapppp
# Taste:Okay cukup rasa.. pedas2 okay
#
# Mungkin akan repeat lagi.. daging halus2 senang untuk kunyah.. rasa semua cukup
# --------------------------------------------------------------------------------
# Review Date: 2024-03-09
# n*****a
# Taste:sedappp
# Quality:bagus. Senang nak simpan.
#
# Taste wise: sedap. Ada rasa manis kicap sikit. Rasa pedas tu ada tapi hujung2 baru rasa pedas tu so enjoy la makan.
# Texture wise: daging dia lerai2 macam serunding so lagi suka kalau daging ketul2.
# Overall: sedap tapi sedap yang biasa je.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-21
# n*****1
# Dah rasa and nothing special about this dendeng to be really honest. Pedas manja2 je and manis. Maybe after this boleh kurangkan manis sikit.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# masdaud1208
# Kali ketiga repeat... Anak² nak buat sahur. Saya suka... Saya suka....
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# sarirahayu5454
# Taste:dendeng Nyet
# Quality:ok
#
# Dendeng Nyet dh sampai.. alhamdulilah smua ok.. xde pecah.. pembungkusan yg sngt tebal.. 👍👍👍👍memng terbaiklah.. dendeng pn sdp
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# sarirahayu5454
# Quality:sambal dendeng Nyet
# Taste:ok
#
# Dendeng Nyet dh smpi.. alhamdulilah smua ckup.. pembungkusan yg sngt tebal.. xde pecah pn.. sambal sedp pedas mnis2👍👍👍👍
# --------------------------------------------------------------------------------
# Review Date: 2024-03-21
# leyla.os
# Quality:Premium
# Taste:Delicious
#
# Sedappp. Recommended to try and buy!
# --------------------------------------------------------------------------------
# Review Date: 2024-02-20
# s*****b
# Taste:rasa manis2 pedas
# Quality:tekstur daging lembut2 kenyal
#
# Blh bg 7/10. Rasa manis kicap, ada jgak rasa rempah2 dia sikit. Tak pedas, budak pn blh mkn.
# 1 paket blh mkn 2-3 org. Mkn dgn nasi putih kosong pn dh sedap.
#
# Expect delay utk postage sbb  paham2 la. Order jumaat smpai selasa KB -JB
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# h*****h
# Taste:sedapss +pedas sikit
# Quality:tip top
#
# 2nd time beliii !! Sbb sedapp mkn dgn nasi impit, rasa mcm raya teruss
# --------------------------------------------------------------------------------
# Review Date: 2024-03-01
# a*****8
# Quality:Gooood
# Taste:Sedapppp
#
# Spiciness: 1/10
# The taste is good, sesuai untuk sahur kalau malas masak. Budak budak pun boleh makan
# --------------------------------------------------------------------------------
# Review Date: 2024-03-17
# n*****a
# Taste:sedapp. Cukup rasa rempah
# Quality:okay
#
# Taste wise: sedap. Ada rasa manis kicap sikit. Rasa pedas tu ada tapi hujung2 baru rasa pedas tu so enjoy la makan.
# Texture wise: daging dia lerai2 macam serunding so lagi suka kalau daging ketul2.
# Overall: sedap tapi sedap yang biasa je.
# --------------------------------------------------------------------------------
# Review Date: 2024-02-23
# womenpuyauuuu
# Taste:sedap
# Quality:cun habis
#
# Rebutan yang berbaloi bagi saya sebab rasa dia semuanya balance and saya suka je danging ceroi sebab lagi senang nak makan. Pedas bagi saya hanya 2/10 buat geli geli manja
# --------------------------------------------------------------------------------
# Review Date: 2024-03-06
# y*****y
# Cara pembungkusan sangat bagus dan baik 👍👍 barang pon dpt dalam keadaan selamat dan sangat baik 👍 boleh beli lagi dari seller ni ♥
# --------------------------------------------------------------------------------
# Review Date: 2024-03-01
# firdausahmad93
# Taste:sedap
#
# Pembungkusan kemas... Penghantaran  cepat... Barang dalam keadaan baik... Boleh repeat order lagi nanti... Tq seller
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# a*****0
# Taste:sedap dooh
# Quality:kepaduan
#
# Kualiti terbaik..sedap..penghantaran pantas..kami sekeluarga suka..
# --------------------------------------------------------------------------------
# Review Date: 2024-02-27
# s*****8
# Taste:Sedap
# Quality:Baik
#
# Rasa sedap. Semua mild je. Tak pedas sangat, tak masin sangat, daging pun ok. Makan panas ok. Makan biasa2 pun ok. Setakat ni semua ok je la mungkin I jenis tak cerewet sangat bab makan. Memang boleh beli lagi la kalau teringin 🤭.
# Beli 4 nak agih2 pada keluarga 🥰.
# Pos pun laju. Sabtu pos dari Kelantan, Isnin dah sampai KL.
# Terima kasih!
# --------------------------------------------------------------------------------
# Review Date: 2024-03-01
# a*****8
# Taste:sedappp
# Quality:good
#
# Spiciness: 1/10
# The taste is good, sesuai untuk sahur kalau malas masak. Budak budak pun boleh makan
# --------------------------------------------------------------------------------
# Review Date: 2024-03-05
# z*****i
# Quality:tiptop
# Taste:rasa dia pedas2 manis. xterlalu pedas dan terlalu manis
#
# daging hancur sesuai utk acik2 yg pakai gigi palsu
# --------------------------------------------------------------------------------
# Review Date: 2024-03-05
# l*****n
# Quality:terbaik
# Taste:sedap
#
# Tq KA. Sedap. Xpedas. Sesuai utk perut org yg xtahan pedas. Yg suka pedas kena mkn gn sambal nyet.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# h*****h
# Quality:good
# Taste:delicious
#
# Akhirnya selepas 3 hari berjuang 🤣🤣
# --------------------------------------------------------------------------------
# No ratings found in the response
# Processing Page: 1
# Review Date: 2024-03-01
# dameer1009
# Quality:Terbaik
# Taste:Sedap sangat
#
# Alhamdulillah rasa sedap. Tak pedas sangat. Daging hancur senang untuk dimakan. Next time kena beli lagi ni untuk stok bulan puasa. Maaf video tiada kena mengena.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-01
# dameer1009
# Taste:Terbaik
# Quality:Sedap sangat
#
# Alhamdulillah rasa sedap. Tak pedas sangat. Daging hancur senang untuk dimakan. Next time kena beli lagi ni untuk stok bulan puasa. Maaf video tiada kena mengena.
# --------------------------------------------------------------------------------
# Review Date: 2024-03-04
# a*****a
# Quality:good
# Taste:good
#
# Dendeng dah selamat sampai lama.. rasa semua okay, sesuai untuk buat sahur bulan ramadhan nanti.. kalau dimakan dengan sambal nyet lagi padu jadinya.. overall semua okay 👌🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-03-04
# a*****a
# Quality:good
# Taste:good
#
# Dendeng dah selamat sampai lama.. rasa semua okay, sesuai untuk buat sahur bulan ramadhan nanti.. kalau dimakan dengan sambal nyet lagi padu jadinya.. overall semua okay 👌🏻
# --------------------------------------------------------------------------------
# Review Date: 2024-03-21
# n*****0
# Tak rasa lagi sebab puasa. 3hari cuba, dapat jugak. Terima kasih
# --------------------------------------------------------------------------------
# Review Date: 2024-02-22
# n*****7
# sedap sangat. untuk saya yang tak makan pedas, saya rasa dendeng ni dah cukup rasa buat saya. kena makan dengan nasi putih panas & telur goreng memang surrr 🔥 saya nak restock untuk bekalan bulan puasa
# --------------------------------------------------------------------------------
# Review Date: 2024-03-01
# w*****a
# sebab ramai dah review jadi tak perlu lah saya review jugak. sedap, lembut dan manis. tolong buat pedas sikit next batch tqqq
# --------------------------------------------------------------------------------
# Review Date: 2024-03-20
# Bg sy dendeng KA ni mmg sedap..secukup rasa..pedas manis sesuai ngn citarasa sy..berbaloi beli utk makan sahur..suami pun cakap sedap..xrugi berebut beli dlm berapa saat sja😆..yg penting support org mlayu islam kita..terbaik KA..sy beli dgn harga tersebut..terima ksih
# --------------------------------------------------------------------------------
# No ratings found in the response

# %%
import datetime
import requests

# URL for Shopee product API endpoint
#product_url = 'https://shopee.com.my/api/v2/item/get'

# Extract shop and item ID from the provided product link (assuming the format is consistent)
#url_params = {'url': 'https://shopee.com.my/-Max-6-packs-Dendeng-Nyet-Berapi-by-Khairulaming-i.364740282.25363171499?sp_atk=b600ac55-0f23-4b9b-af94-18a0d7fbca5d&is_from_login=true'}



try:
    # Send API request to get product details
    response = requests.get(product_url, params=url_params)
    response.raise_for_status()  # Raise an exception for non-200 status codes

    data = response.json()

    if 'data' in data and 'item' in data['data']:
        shop_id = data['data']['item']['shopid']
        item_id = data['data']['item']['itemid']

        # Limit for the number of pages (3 pages)
        page_limit = 3

        offset = 0
        for page_number in range(page_limit):
            ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'

            try:
                # Send API request to get ratings
                response = requests.get(ratings_url)
                response.raise_for_status()  # Raise an exception for non-200 status codes

                data = response.json()

                if 'data' in data and 'ratings' in data['data'] and data['data']['ratings']:
                    for rating in data['data']['ratings']:
                        try:
                            datetime_str = convert_ctime_to_datetime(rating['ctime'])
                            date_only = extract_date(datetime_str)
                            if date_only:
                                print(f"Review Date: {date_only}")
                            else:
                                print("Failed to extract date from ctime")
                        except KeyError:
                            print("Review is missing a 'ctime' field")
                        print(rating['author_username'])
                        print(rating['comment'])
                        print('-' * 80)
                else:
                    print("No ratings found in the response")

            except requests.exceptions.RequestException as e:
                print(f"Error making API request: {e}")

            offset += 20

        # Include functions for date extraction (assuming they are defined elsewhere)
        
        def extract_date(datetime_str):
            """Extracts only the date portion (YYYY-MM-DD) from a formatted datetime string.

            Args:
                datetime_str: The string containing the date and time in a format like "YYYY-MM-DD HH:MM".

            Returns:
                The extracted date portion as a string (YYYY-MM-DD), or None if the format is invalid.
            """
            if datetime_str:
                try:
                    # Split the string at the space separator
                    date_part, _ = datetime_str.split(" ")
                    return date_part
                except ValueError:
                    print(f"Invalid datetime format: {datetime_str}")
                    return None
            else:
                return None
        def convert_ctime_to_datetime(ctime_value):
            """Converts a ctime value (potentially a timestamp) to a datetime object.

            Args:
                ctime_value: The value retrieved from the 'ctime' field in the API response.

            Returns:
                A datetime object representing the converted time, or None if conversion fails.
            """

            try:
                timestamp = int(ctime_value)
                datetime_obj = datetime.datetime.fromtimestamp(timestamp)
                return datetime_obj.strftime("%Y-%m-%d %H:%M")  # Format as "YYYY-MM-DD HH:MM"
            except (ValueError, TypeError):
                print(f"Error converting ctime value: {ctime_value}")
                return None
    else:
        print("Error: Could not retrieve product information")

except requests.exceptions.RequestException as e:
    print(f"Error fetching product details: {e}")
